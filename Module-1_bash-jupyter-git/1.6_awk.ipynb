# %% [markdown]
# # 1.6 awk
#
# This notebook will demonstrate the basics of using `awk` to extract specific fields from within data files.

# %% [markdown]
# #### manual inspection of `artists.txt`
#
# There are at least two options for loading `artists.txt` into your favorite spreadsheet program:
#
# * you already have the file on your computer somewhere on your file system, so you can load it from there (if you can figure it out)
# * you can download the text file from https://raw.githubusercontent.com/SuLab/Applied-Bioinformatics/master/Module-1_bash-jupyter-git/data/art/artists.txt
#
# Note that every row has four columns.

# %% [markdown]
# #### confirm using awk that each row has four columns
# Find and fix the error.
#
# ```
# %%bash
# awk '{print NF}' artists.txt
# ```

# %%
# %%bash
# cd data/art
# awk '{print NF}' artists.txt
# Out:
# 8
# 6
# 8
# 7
# 7
# 7
# 11
# 6
# 10
# 10
# 9
# 8
# 7
# 13
# 8
# 14
# 7
# 9
# 9
# 10
# 9
# 12
# 8
# 9
# 7
# 7
# 7
# 7
# 7
# 8
# 7
# 8
# 7
# 6
# 6
# 7
# 7
# 7
# 11
# 12
# 8
# 6
# 7
# 9
# 7
# 12
# 6
# 7
# 7
# 9
# 9
# 7
# 7
# 8
# 8
# 8
# 9
# 9
# 7
# 6
# 10
# 7
# 7
# 7
# 9
# 7
# 7
# 7
# 7
# 7
# 9
# 7
# 7
# 10
# 12
# 7
# 7
# 9
# 7
# 7
# 10
# 6
# 7
# 10
# 9
# 7
# 9
# 8
# 9
# 7
# 7
# 11
# 12
# 7
# 9
# 13
# 7
# 7
# 10
# 7
# 7
# 8
# 11
# 8
# 8
# 6
# 9
# 13
# 8
# 6
# 7
# 9
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 11
# 8
# 11
# 7
# 9
# 9
# 7
# 10
# 8
# 7
# 13
# 11
# 9
# 9
# 9
# 14
# 12
# 8
# 7
# 9
# 8
# 11
# 7
# 8
# 10
# 7
# 7
# 8
# 8

# %%
# %%bash
# awk '{print NF}' artists.txt
# Out:
# awk: can't open file artists.txt
#  source line number 1

# %%
# %%bash
# awk '{print NF}' data/art/artists.txt
# Out:
# 8
# 6
# 8
# 7
# 7
# 7
# 11
# 6
# 10
# 10
# 9
# 8
# 7
# 13
# 8
# 14
# 7
# 9
# 9
# 10
# 9
# 12
# 8
# 9
# 7
# 7
# 7
# 7
# 7
# 8
# 7
# 8
# 7
# 6
# 6
# 7
# 7
# 7
# 11
# 12
# 8
# 6
# 7
# 9
# 7
# 12
# 6
# 7
# 7
# 9
# 9
# 7
# 7
# 8
# 8
# 8
# 9
# 9
# 7
# 6
# 10
# 7
# 7
# 7
# 9
# 7
# 7
# 7
# 7
# 7
# 9
# 7
# 7
# 10
# 12
# 7
# 7
# 9
# 7
# 7
# 10
# 6
# 7
# 10
# 9
# 7
# 9
# 8
# 9
# 7
# 7
# 11
# 12
# 7
# 9
# 13
# 7
# 7
# 10
# 7
# 7
# 8
# 11
# 8
# 8
# 6
# 9
# 13
# 8
# 6
# 7
# 9
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 11
# 8
# 11
# 7
# 9
# 9
# 7
# 10
# 8
# 7
# 13
# 11
# 9
# 9
# 9
# 14
# 12
# 8
# 7
# 9
# 8
# 11
# 7
# 8
# 10
# 7
# 7
# 8
# 8

# %%
# %%bash
# awk '{print $NF}' artists.txt
# Out:
# awk: can't open file artists.txt
#  source line number 1

# %%
# %%bash
# awk '{print $NF}' data/art/artists.txt
# Out:
# (Augsburg)
# painter
# sculptor
# (Pest)
# artist
# architect
# (Franconia)
# painter
# Tyrol)
# Petersburg)
# Petersburg)
# (Florence)
# (Florence)
# (Rome)
# (Siena)
# (Ferrara)
# (Rome)
# (Florence)
# (Florence)
# (Mantua)
# Gimignano)
# sculptor
# painter
# painter
# (Stockholm)
# (Paris)
# artist
# painter
# (Florence)
# (Paris)
# goldsmith
# (Venice)
# (Bologna)
# sculptor
# painter
# (Langres)
# (Rome)
# painter
# (Verona)
# (Rome)
# (London)
# painter
# (Venice)
# (Amsterdam)
# (Florence)
# (Italy)
# sculptor
# (Amsterdam)
# (Antwerp)
# (Antwerp)
# (Antwerp)
# (Deventer)
# (Utrecht)
# (Feltre)
# (Livorno)
# (Vienna)
# (Stockholm)
# (Stockholm)
# (Rome)
# painter
# sculptor
# (Rome)
# painter
# (London)
# (Haarlem)
# (Brussels)
# painter
# painter
# painter
# painter
# (Berlin)
# (Italy)
# painter
# (London)
# (Haarlem)
# (Munich)
# (Rotterdam)
# (Rotterdam)
# painter
# painter
# (Nuremberg)
# painter
# painter
# architect
# (Amsterdam)
# painter
# (Münster)
# (Haarlem)
# Petersburg)
# painter
# (Vienna)
# (Vienna)
# (Amsterdam)
# (Augsburg)
# (London)
# painter
# (Amsterdam)
# (Amsterdam)
# (Westphalie)
# (Berlin)
# painter
# (Copenhagen)
# (Huesca)
# potter
# (Bologna)
# painter
# (Rome)
# (Venice)
# (Amsterdam)
# painter
# (Vienna)
# architect
# (Dusseldorf)
# (Munich)
# (Nancy)
# (Nancy)
# (London)
# (Paris)
# architect
# (Florence)
# (Milan)
# (Amsterdam)
# (Amsterdam)
# painter
# (Antwerp)
# (Florence)
# (Delft)
# (Antwerp)
# painter
# (Amsterdam)
# (London)
# (Siena)
# (Florence)
# (Siena)
# (Rimini)
# (Siena)
# artist
# (Parma)
# (Madrid)
# painter
# (London)
# (Crete)
# (Alba)
# (Bologna)
# (Venice)
# (Urbino)
# (Rome)
# (Rome)
# architect
# (Florence)

# %% [markdown]
# #### Print the third column
# Find and fix the error.
# ```
# %%bash
# awk '{print $3}' artists.txt
# ```

# %%
# %%bash
# awk '{FS="\t";print $3}' data/art/artists.txt
# Out:
# (1581-1662)
# Romanticism
# Romanticism
# Romanticism
# Baroque
# Romanticism
# Baroque
# Realism
# Northern Renaissance
# Realism
# Romanticism
# Baroque
# Baroque
# Early Renaissance
# Medieval
# Early Renaissance
# Realism
# Medieval
# Medieval
# Early Renaissance
# High Renaissance
# Early Renaissance
# Baroque
# Baroque
# Baroque
# Rococo
# Neoclassicism
# Impressionism
# Baroque
# Baroque
# Mannerism
# Baroque
# Baroque
# Rococo
# Romanticism
# Baroque
# Baroque
# Rococo
# Baroque
# Baroque
# Mannerism
# Romanticism
# Rococo
# Baroque
# Baroque
# Baroque
# Neoclassicism
# Baroque
# Baroque
# Baroque
# Baroque
# Baroque
# Baroque
# Baroque
# Neoclassicism
# Mannerism
# Baroque
# Baroque
# Baroque
# Baroque
# Mannerism
# Romanticism
# Baroque
# Baroque
# Baroque
# Realism
# Romanticism
# Romanticism
# Romanticism
# Rococo
# Baroque
# Neoclassicism
# Baroque
# Baroque
# Baroque
# Rococo
# Rococo
# Rococo
# Neoclassicism
# Romanticism
# Northern Renaissance
# Romanticism
# Romanticism
# Baroque
# Baroque
# Romanticism
# Northern Renaissance
# Baroque
# Baroque
# Neoclassicism
# Rococo
# Mannerism
# Baroque
# Baroque
# Baroque
# Baroque
# Baroque
# Baroque
# Northern Renaissance
# Romanticism
# Mannerism
# Realism
# Early Renaissance
# High Renaissance
# Mannerism
# Realism
# Baroque
# High Renaissance
# Baroque
# Romanticism
# Mannerism
# Baroque
# Realism
# Romanticism
# Baroque
# Baroque
# Baroque
# Realism
# Neoclassicism
# Neoclassicism
# Baroque
# Baroque
# Baroque
# Baroque
# Baroque
# Early Renaissance
# Baroque
# Baroque
# Northern Renaissance
# Northern Renaissance
# Neoclassicism
# Medieval
# Early Renaissance
# Medieval
# Early Renaissance
# Medieval
# High Renaissance
# High Renaissance
# Neoclassicism
# Realism
# Rococo
# Medieval
# Early Renaissance
# Baroque
# Medieval
# Early Renaissance
# Mannerism
# Mannerism
# Early Renaissance
# Early Renaissance

# %%
# %%bash
# awk '{ print $3 }' artists.txt
# Out:
# awk: can't open file artists.txt
#  source line number 1

# %% [markdown]
# #### Use `uniq` (and another command) to find the most common art periods
# Find and fix the error(s).
# ```
# %%bash
# awk '{print $3}' artists.txt | uniq
# ```

# %%
# %%bash
# awk '{print $3}' data/art/artists.txt | uniq
# Out:
# (1581-1662)
# (1771-1839)
# Karl
# (1802-1868)
# (1703-1761)
# von
# (see
# (1857-1920)
# (active
# Konstantinovich
# Karlovich
# (1619-c.
# (1577-1640)
# (see
# BARTOLO
# FERRARA
# (1822-1892)
# (c.
# (active
# (1492-1530)
# (see
# Werner
# VARALLO
# (1701-1750)
# (1729-1785)
# (1738-1794)
# Charles
# (1576-1645)
# (1674-1749)
# (active
# (c.
# (1633-1696)
# (1727-1788)
# (1800-1874)
# (1608-1667)
# (1578-1644)
# Antoine
# (see
# Paolo
# c.
# (1828-1906)
# (1705-1789)
# van
# (1555-1630)
# (see
# (1789-1869)
# (1584-1635)
# (1629-1670)
# the
# (1617-1681)
# (1588-1629)
# (active
# Maria
# (c.
# the
# (1611-1650)
# (1616-1695)
# Danielsz
# (1809-1877)
# Godfrey
# (1639-1681)
# (c.
# (1821-1909)
# Geertruida
# Augustus
# Derk
# Frederik
# Wenceslaus
# (1725-1804)
# (c.
# (see
# (1749-1822)
# (1751-1779)
# I
# II
# von
# (c.
# (1810-1848)
# Anton
# (see
# (c.
# Cornelis
# (c.
# Filippovich
# Wilhelm
# (1730-1802)
# (see
# ten
# (1586-1642)
# de
# (1619-1688)
# (1609-1656)
# Soest
# (1799-1853)
# von
# Frederik
# de
# (c
# dell'
# (1836-1868)
# Ubaldo
# di
# van
# (1743-1809)
# (1538-1591)
# AREBO,
# (1827-1905)
# (1786-1862)
# (1700-1759)
# (1705-1778)
# (1728-1792)
# (1818-1881)
# Fredrik
# (1764-1849)
# (1630-1709)
# (see
# (c.
# UTRECHT
# (1587-1661)
# (ca.
# van
# (1633-1690)
# ORT
# (1508-1575)
# (1767-1849)
# SIENA
# POLO
# VENTURA
# DUCCIO
# GIOVANNI
# (see
# Francesco
# Antonio
# Konstantinovich
# van
# (?-c.
# d'
# (1578-1660)
# (died
# (c.
# (1553-1615)
# (1558-1601)
# Battista
# (1474-1515)

# %% [markdown]
# ## Homework

# %% [markdown]
# ### HW1: Repeat the above command (finding the most common art periods) restricting to Dutch painters only.
# HINT: start by searching/filtering for Dutch painters...

# %%
# %%bash
# grep -c "Dutch painter" data/art/artists.txt | awk '{print $3}' | uniq

# %%
# %%bash
# cd data/art
# grep -c "Dutch painter" artists.txt
# Out:
# 25

# %%
# %%bash
# cd data/art
# grep -c "Dutch painter" artists.txt | awk "{print $3}" | uniq
# Out:
# 25

# %%
# %%bash
# cd data/art
# grep -c "Dutch painter" artists.txt | awk '{print $3}' | uniq

# %%
# %%bash
# cd data/art

# %% [markdown]
# ### HW2: Find the most common last names among all artists in `artists.txt`.
# HINT: you will use `awk`, `sort`, and `uniq`, and you may use one or more of those commands multiple times
